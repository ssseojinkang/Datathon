# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# 시즌 시작일과 종료일 설정
start_date = datetime(2021, 4, 1)  # 2021 시즌 첫 게임 날짜
end_date = datetime(2024, 7, 5)  # 2024년 7월 5일

# 데이터를 저장할 빈 DataFrame 생성
columns = ["Date", "Rank", "Team", "Year", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SB", "CS", "GO", "FO", "BB", "HP", "IB", "SO", "GDP", "SH", "SF", "AVG", "OBP", "SLG", "OPS"]
team_batting_data = pd.DataFrame(columns=columns)

# 날짜별로 데이터를 가져오기
current_date = start_date
while current_date <= end_date:
    # 날짜를 URL에 맞는 형식으로 변환
    date_str = current_date.strftime("%m-%d")  # 'MM-DD' 형식
    year_str = current_date.year  # 현재 날짜의 연도

    # URL 생성 (연도도 동적으로 바뀌게)
    url = f"https://statiz.sporki.com/stats/?m=team&m2=batting&m3=situation1&so=&ob=&year={year_str}&sy={year_str}&ey={year_str}&te=&po=&lt=10100&reg=&pe=I&ds={date_str}&de={date_str}&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2="

    # 페이지 가져오기
    response = requests.get(url)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')

    # 테이블 추출
    tables = soup.find_all('table')
    if len(tables) < 2:  # 테이블이 없으면 다음 날짜로 넘어감
        print(f"{current_date.strftime('%Y-%m-%d')} 데이터 없음")
        current_date += timedelta(days=1)
        continue

    table = tables[1]
    rows = table.find('tbody').find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        data.append(cols)

    # DataFrame 변환
    df = pd.DataFrame(data, columns=columns[1:])  # "Date" 제외한 열
    df.insert(0, "Date", current_date.strftime('%Y-%m-%d'))  # Date 열 추가

    # 전체 데이터에 합치기
    team_batting_data = pd.concat([team_batting_data, df], ignore_index=True)
    print(f"{current_date.strftime('%Y-%m-%d')} 데이터 수집 완료")

    # 다음 날짜로 이동
    current_date += timedelta(days=1)

print("모든 데이터 수집 완료")
# 최종 데이터프레임 출력
team_batting_data
# Out:
# 2021-04-01 데이터 수집 완료
# 2021-04-02 데이터 수집 완료
# 2021-04-03 데이터 수집 완료
# 2021-04-04 데이터 수집 완료
# 2021-04-05 데이터 수집 완료
# 2021-04-06 데이터 수집 완료
# 2021-04-07 데이터 수집 완료
# 2021-04-08 데이터 수집 완료
# 2021-04-09 데이터 수집 완료
# 2021-04-10 데이터 수집 완료
# 2021-04-11 데이터 수집 완료
# 2021-04-12 데이터 수집 완료
# 2021-04-13 데이터 수집 완료
# 2021-04-14 데이터 수집 완료
# 2021-04-15 데이터 수집 완료
# 2021-04-16 데이터 수집 완료
# 2021-04-17 데이터 수집 완료
# 2021-04-18 데이터 수집 완료
# 2021-04-19 데이터 수집 완료
# 2021-04-20 데이터 수집 완료
# 2021-04-21 데이터 수집 완료
# 2021-04-22 데이터 수집 완료
# 2021-04-23 데이터 수집 완료
# 2021-04-24 데이터 수집 완료
# 2021-04-25 데이터 수집 완료
# 2021-04-26 데이터 수집 완료
# 2021-04-27 데이터 수집 완료
# 2021-04-28 데이터 수집 완료
# 2021-04-29 데이터 수집 완료
# 2021-04-30 데이터 수집 완료
# 2021-05-01 데이터 수집 완료
# 2021-05-02 데이터 수집 완료
# 2021-05-03 데이터 수집 완료
# 2021-05-04 데이터 수집 완료
# 2021-05-05 데이터 수집 완료
# 2021-05-06 데이터 수집 완료
# 2021-05-07 데이터 수집 완료
# 2021-05-08 데이터 수집 완료
# 2021-05-09 데이터 수집 완료
# 2021-05-10 데이터 수집 완료
# 2021-05-11 데이터 수집 완료
# 2021-05-12 데이터 수집 완료
# 2021-05-13 데이터 수집 완료
# 2021-05-14 데이터 수집 완료
# 2021-05-15 데이터 수집 완료
# 2021-05-16 데이터 수집 완료
# 2021-05-17 데이터 수집 완료
# 2021-05-18 데이터 수집 완료
# 2021-05-19 데이터 수집 완료
# 2021-05-20 데이터 수집 완료
# 2021-05-21 데이터 수집 완료
# 2021-05-22 데이터 수집 완료
# 2021-05-23 데이터 수집 완료
# 2021-05-24 데이터 수집 완료
# 2021-05-25 데이터 수집 완료
# 2021-05-26 데이터 수집 완료
# 2021-05-27 데이터 수집 완료
# 2021-05-28 데이터 수집 완료
# 2021-05-29 데이터 수집 완료
# 2021-05-30 데이터 수집 완료
# 2021-05-31 데이터 수집 완료
# 2021-06-01 데이터 수집 완료
# 2021-06-02 데이터 수집 완료
# 2021-06-03 데이터 수집 완료
# 2021-06-04 데이터 수집 완료
# 2021-06-05 데이터 수집 완료
# 2021-06-06 데이터 수집 완료
# 2021-06-07 데이터 수집 완료
# 2021-06-08 데이터 수집 완료
# 2021-06-09 데이터 수집 완료
# 2021-06-10 데이터 수집 완료
# 2021-06-11 데이터 수집 완료
# 2021-06-12 데이터 수집 완료
# 2021-06-13 데이터 수집 완료
# 2021-06-14 데이터 수집 완료
# 2021-06-15 데이터 수집 완료
# 2021-06-16 데이터 수집 완료
# 2021-06-17 데이터 수집 완료
# 2021-06-18 데이터 수집 완료
# 2021-06-19 데이터 수집 완료
# 2021-06-20 데이터 수집 완료
# 2021-06-21 데이터 수집 완료
# 2021-06-22 데이터 수집 완료
# 2021-06-23 데이터 수집 완료
# 2021-06-24 데이터 수집 완료
# 2021-06-25 데이터 수집 완료
# 2021-06-26 데이터 수집 완료
# 2021-06-27 데이터 수집 완료
# 2021-06-28 데이터 수집 완료
# 2021-06-29 데이터 수집 완료
# 2021-06-30 데이터 수집 완료
# 2021-07-01 데이터 수집 완료
# 2021-07-02 데이터 수집 완료
# 2021-07-03 데이터 수집 완료
# 2021-07-04 데이터 수집 완료
# 2021-07-05 데이터 수집 완료
# 2021-07-06 데이터 수집 완료
# 2021-07-07 데이터 수집 완료
# 2021-07-08 데이터 수집 완료
# 2021-07-09 데이터 수집 완료
# 2021-07-10 데이터 수집 완료
# 2021-07-11 데이터 수집 완료
# 2021-07-12 데이터 수집 완료
# 2021-07-13 데이터 수집 완료
# 2021-07-14 데이터 수집 완료
# 2021-07-15 데이터 수집 완료
# 2021-07-16 데이터 수집 완료
# 2021-07-17 데이터 수집 완료
# 2021-07-18 데이터 수집 완료
# 2021-07-19 데이터 수집 완료
# 2021-07-20 데이터 수집 완료
# 2021-07-21 데이터 수집 완료
# 2021-07-22 데이터 수집 완료
# 2021-07-23 데이터 수집 완료
# 2021-07-24 데이터 수집 완료
# 2021-07-25 데이터 수집 완료
# 2021-07-26 데이터 수집 완료
# 2021-07-27 데이터 수집 완료
# 2021-07-28 데이터 수집 완료
# 2021-07-29 데이터 수집 완료
# 2021-07-30 데이터 수집 완료
# 2021-07-31 데이터 수집 완료
# 2021-08-01 데이터 수집 완료
# 2021-08-02 데이터 수집 완료
# 2021-08-03 데이터 수집 완료
# 2021-08-04 데이터 수집 완료
# 2021-08-05 데이터 수집 완료
# 2021-08-06 데이터 수집 완료
# 2021-08-07 데이터 수집 완료
# 2021-08-08 데이터 수집 완료
# 2021-08-09 데이터 수집 완료
# 2021-08-10 데이터 수집 완료
# 2021-08-11 데이터 수집 완료
# 2021-08-12 데이터 수집 완료
# 2021-08-13 데이터 수집 완료
# 2021-08-14 데이터 수집 완료
# 2021-08-15 데이터 수집 완료
# 2021-08-16 데이터 수집 완료
# 2021-08-17 데이터 수집 완료
# 2021-08-18 데이터 수집 완료
# 2021-08-19 데이터 수집 완료
# 2021-08-20 데이터 수집 완료
# 2021-08-21 데이터 수집 완료
# 2021-08-22 데이터 수집 완료
# 2021-08-23 데이터 수집 완료
# 2021-08-24 데이터 수집 완료
# 2021-08-25 데이터 수집 완료
# 2021-08-26 데이터 수집 완료
# 2021-08-27 데이터 수집 완료
# 2021-08-28 데이터 수집 완료
# 2021-08-29 데이터 수집 완료
# 2021-08-30 데이터 수집 완료
# 2021-08-31 데이터 수집 완료
# 2021-09-01 데이터 수집 완료
# 2021-09-02 데이터 수집 완료
# 2021-09-03 데이터 수집 완료
# 2021-09-04 데이터 수집 완료
# 2021-09-05 데이터 수집 완료
# 2021-09-06 데이터 수집 완료
# 2021-09-07 데이터 수집 완료
# 2021-09-08 데이터 수집 완료
# 2021-09-09 데이터 수집 완료
# 2021-09-10 데이터 수집 완료
# 2021-09-11 데이터 수집 완료
# 2021-09-12 데이터 수집 완료
# 2021-09-13 데이터 수집 완료
# 2021-09-14 데이터 수집 완료
# 2021-09-15 데이터 수집 완료
# 2021-09-16 데이터 수집 완료
# 2021-09-17 데이터 수집 완료
# 2021-09-18 데이터 수집 완료
# 2021-09-19 데이터 수집 완료
# 2021-09-20 데이터 수집 완료
# 2021-09-21 데이터 수집 완료
# 2021-09-22 데이터 수집 완료
# 2021-09-23 데이터 수집 완료
# 2021-09-24 데이터 수집 완료
# 2021-09-25 데이터 수집 완료
# 2021-09-26 데이터 수집 완료
# 2021-09-27 데이터 수집 완료
# 2021-09-28 데이터 수집 완료
# 2021-09-29 데이터 수집 완료
# 2021-09-30 데이터 수집 완료
# 2021-10-01 데이터 수집 완료
# 2021-10-02 데이터 수집 완료
# 2021-10-03 데이터 수집 완료
# 2021-10-04 데이터 수집 완료
# 2021-10-05 데이터 수집 완료
# 2021-10-06 데이터 수집 완료
# 2021-10-07 데이터 수집 완료
# 2021-10-08 데이터 수집 완료
# 2021-10-09 데이터 수집 완료
# 2021-10-10 데이터 수집 완료
# 2021-10-11 데이터 수집 완료
# 2021-10-12 데이터 수집 완료
# 2021-10-13 데이터 수집 완료
# 2021-10-14 데이터 수집 완료
# 2021-10-15 데이터 수집 완료
# 2021-10-16 데이터 수집 완료
# 2021-10-17 데이터 수집 완료
# 2021-10-18 데이터 수집 완료
# 2021-10-19 데이터 수집 완료
# 2021-10-20 데이터 수집 완료
# 2021-10-21 데이터 수집 완료
# 2021-10-22 데이터 수집 완료
# 2021-10-23 데이터 수집 완료
# 2021-10-24 데이터 수집 완료
# 2021-10-25 데이터 수집 완료
# 2021-10-26 데이터 수집 완료
# 2021-10-27 데이터 수집 완료
# 2021-10-28 데이터 수집 완료
# 2021-10-29 데이터 수집 완료
# 2021-10-30 데이터 수집 완료
# 2021-10-31 데이터 수집 완료
# 2021-11-01 데이터 수집 완료
# 2021-11-02 데이터 수집 완료
# 2021-11-03 데이터 수집 완료
# 2021-11-04 데이터 수집 완료
# 2021-11-05 데이터 수집 완료
# 2021-11-06 데이터 수집 완료
# 2021-11-07 데이터 수집 완료
# 2021-11-08 데이터 수집 완료
# 2021-11-09 데이터 수집 완료
# 2021-11-10 데이터 수집 완료
# 2021-11-11 데이터 수집 완료
# 2021-11-12 데이터 수집 완료
# 2021-11-13 데이터 수집 완료
# 2021-11-14 데이터 수집 완료
# 2021-11-15 데이터 수집 완료
# 2021-11-16 데이터 수집 완료
# 2021-11-17 데이터 수집 완료
# 2021-11-18 데이터 수집 완료
# 2021-11-19 데이터 수집 완료
# 2021-11-20 데이터 수집 완료
# 2021-11-21 데이터 수집 완료
# 2021-11-22 데이터 수집 완료
# 2021-11-23 데이터 수집 완료
# 2021-11-24 데이터 수집 완료
# 2021-11-25 데이터 수집 완료
# 2021-11-26 데이터 수집 완료
# 2021-11-27 데이터 수집 완료
# 2021-11-28 데이터 수집 완료
# 2021-11-29 데이터 수집 완료
# 2021-11-30 데이터 수집 완료
# 2021-12-01 데이터 수집 완료
# 2021-12-02 데이터 수집 완료
# 2021-12-03 데이터 수집 완료
# 2021-12-04 데이터 수집 완료
# 2021-12-05 데이터 수집 완료
# 2021-12-06 데이터 수집 완료
# 2021-12-07 데이터 수집 완료
# 2021-12-08 데이터 수집 완료
# 2021-12-09 데이터 수집 완료
# 2021-12-10 데이터 수집 완료
# 2021-12-11 데이터 수집 완료
# 2021-12-12 데이터 수집 완료
# 2021-12-13 데이터 수집 완료
# 2021-12-14 데이터 수집 완료
# 2021-12-15 데이터 수집 완료
# 2021-12-16 데이터 수집 완료
# 2021-12-17 데이터 수집 완료
# 2021-12-18 데이터 수집 완료
# 2021-12-19 데이터 수집 완료
# 2021-12-20 데이터 수집 완료
# 2021-12-21 데이터 수집 완료
# 2021-12-22 데이터 수집 완료
# 2021-12-23 데이터 수집 완료
# 2021-12-24 데이터 수집 완료
# 2021-12-25 데이터 수집 완료
# 2021-12-26 데이터 수집 완료
# 2021-12-27 데이터 수집 완료
# 2021-12-28 데이터 수집 완료
# 2021-12-29 데이터 수집 완료
# 2021-12-30 데이터 수집 완료
# 2021-12-31 데이터 수집 완료
# 2022-01-01 데이터 수집 완료
# 2022-01-02 데이터 수집 완료
# 2022-01-03 데이터 수집 완료
# 2022-01-04 데이터 수집 완료
# 2022-01-05 데이터 수집 완료
# 2022-01-06 데이터 수집 완료
# 2022-01-07 데이터 수집 완료
# 2022-01-08 데이터 수집 완료
# 2022-01-09 데이터 수집 완료
# 2022-01-10 데이터 수집 완료
# 2022-01-11 데이터 수집 완료
# 2022-01-12 데이터 수집 완료
# 2022-01-13 데이터 수집 완료
# 2022-01-14 데이터 수집 완료
# 2022-01-15 데이터 수집 완료
# 2022-01-16 데이터 수집 완료
# 2022-01-17 데이터 수집 완료
# 2022-01-18 데이터 수집 완료
# 2022-01-19 데이터 수집 완료
# 2022-01-20 데이터 수집 완료
# 2022-01-21 데이터 수집 완료
# 2022-01-22 데이터 수집 완료
# 2022-01-23 데이터 수집 완료
# 2022-01-24 데이터 수집 완료
# 2022-01-25 데이터 수집 완료
# 2022-01-26 데이터 수집 완료
# 2022-01-27 데이터 수집 완료
# 2022-01-28 데이터 수집 완료
# 2022-01-29 데이터 수집 완료
# 2022-01-30 데이터 수집 완료
# 2022-01-31 데이터 수집 완료
# 2022-02-01 데이터 수집 완료
# 2022-02-02 데이터 수집 완료
# 2022-02-03 데이터 수집 완료
# 2022-02-04 데이터 수집 완료
# 2022-02-05 데이터 수집 완료
# 2022-02-06 데이터 수집 완료
# 2022-02-07 데이터 수집 완료
# 2022-02-08 데이터 수집 완료
# 2022-02-09 데이터 수집 완료
# 2022-02-10 데이터 수집 완료
# 2022-02-11 데이터 수집 완료
# 2022-02-12 데이터 수집 완료
# 2022-02-13 데이터 수집 완료
# 2022-02-14 데이터 수집 완료
# 2022-02-15 데이터 수집 완료
# 2022-02-16 데이터 수집 완료
# 2022-02-17 데이터 수집 완료
# 2022-02-18 데이터 수집 완료
# 2022-02-19 데이터 수집 완료
# 2022-02-20 데이터 수집 완료
# 2022-02-21 데이터 수집 완료
# 2022-02-22 데이터 수집 완료
# 2022-02-23 데이터 수집 완료
# 2022-02-24 데이터 수집 완료
# 2022-02-25 데이터 수집 완료
# 2022-02-26 데이터 수집 완료
# 2022-02-27 데이터 수집 완료
# 2022-02-28 데이터 수집 완료
# 2022-03-01 데이터 수집 완료
# 2022-03-02 데이터 수집 완료
# 2022-03-03 데이터 수집 완료
# 2022-03-04 데이터 수집 완료
# 2022-03-05 데이터 수집 완료
# 2022-03-06 데이터 수집 완료
# 2022-03-07 데이터 수집 완료
# 2022-03-08 데이터 수집 완료
# 2022-03-09 데이터 수집 완료
# 2022-03-10 데이터 수집 완료
# 2022-03-11 데이터 수집 완료
# 2022-03-12 데이터 수집 완료
# 2022-03-13 데이터 수집 완료
# 2022-03-14 데이터 수집 완료
# 2022-03-15 데이터 수집 완료
# 2022-03-16 데이터 수집 완료
# 2022-03-17 데이터 수집 완료
# 2022-03-18 데이터 수집 완료
# 2022-03-19 데이터 수집 완료
# 2022-03-20 데이터 수집 완료
# 2022-03-21 데이터 수집 완료
# 2022-03-22 데이터 수집 완료
# 2022-03-23 데이터 수집 완료
# 2022-03-24 데이터 수집 완료
# 2022-03-25 데이터 수집 완료
# 2022-03-26 데이터 수집 완료
# 2022-03-27 데이터 수집 완료
# 2022-03-28 데이터 수집 완료
# 2022-03-29 데이터 수집 완료
# 2022-03-30 데이터 수집 완료
# 2022-03-31 데이터 수집 완료
# 2022-04-01 데이터 수집 완료
# 2022-04-02 데이터 수집 완료
# 2022-04-03 데이터 수집 완료
# 2022-04-04 데이터 수집 완료
# 2022-04-05 데이터 수집 완료
# 2022-04-06 데이터 수집 완료
# 2022-04-07 데이터 수집 완료
# 2022-04-08 데이터 수집 완료
# 2022-04-09 데이터 수집 완료
# 2022-04-10 데이터 수집 완료
# 2022-04-11 데이터 수집 완료
# 2022-04-12 데이터 수집 완료
# 2022-04-13 데이터 수집 완료
# 2022-04-14 데이터 수집 완료
# 2022-04-15 데이터 수집 완료
# 2022-04-16 데이터 수집 완료
# 2022-04-17 데이터 수집 완료
# 2022-04-18 데이터 수집 완료
# 2022-04-19 데이터 수집 완료
# 2022-04-20 데이터 수집 완료
# 2022-04-21 데이터 수집 완료
# 2022-04-22 데이터 수집 완료
# 2022-04-23 데이터 수집 완료
# 2022-04-24 데이터 수집 완료
# 2022-04-25 데이터 수집 완료
# 2022-04-26 데이터 수집 완료
# 2022-04-27 데이터 수집 완료
# 2022-04-28 데이터 수집 완료
# 2022-04-29 데이터 수집 완료
# 2022-04-30 데이터 수집 완료
# 2022-05-01 데이터 수집 완료
# 2022-05-02 데이터 수집 완료
# 2022-05-03 데이터 수집 완료
# 2022-05-04 데이터 수집 완료
# 2022-05-05 데이터 수집 완료
# 2022-05-06 데이터 수집 완료
# 2022-05-07 데이터 수집 완료
# 2022-05-08 데이터 수집 완료
# 2022-05-09 데이터 수집 완료
# 2022-05-10 데이터 수집 완료
# 2022-05-11 데이터 수집 완료
# 2022-05-12 데이터 수집 완료
# 2022-05-13 데이터 수집 완료
# 2022-05-14 데이터 수집 완료
# 2022-05-15 데이터 수집 완료
# 2022-05-16 데이터 수집 완료
# 2022-05-17 데이터 수집 완료
# 2022-05-18 데이터 수집 완료
# 2022-05-19 데이터 수집 완료
# 2022-05-20 데이터 수집 완료
# 2022-05-21 데이터 수집 완료
# 2022-05-22 데이터 수집 완료
# 2022-05-23 데이터 수집 완료
# 2022-05-24 데이터 수집 완료
# 2022-05-25 데이터 수집 완료
# 2022-05-26 데이터 수집 완료
# 2022-05-27 데이터 수집 완료
# 2022-05-28 데이터 수집 완료
# 2022-05-29 데이터 수집 완료
# 2022-05-30 데이터 수집 완료
# 2022-05-31 데이터 수집 완료
# 2022-06-01 데이터 수집 완료
# 2022-06-02 데이터 수집 완료
# 2022-06-03 데이터 수집 완료
# 2022-06-04 데이터 수집 완료
# 2022-06-05 데이터 수집 완료
# 2022-06-06 데이터 수집 완료
# 2022-06-07 데이터 수집 완료
# 2022-06-08 데이터 수집 완료
# 2022-06-09 데이터 수집 완료
# 2022-06-10 데이터 수집 완료
# 2022-06-11 데이터 수집 완료
# 2022-06-12 데이터 수집 완료
# 2022-06-13 데이터 수집 완료
# 2022-06-14 데이터 수집 완료
# 2022-06-15 데이터 수집 완료
# 2022-06-16 데이터 수집 완료
# 2022-06-17 데이터 수집 완료
# 2022-06-18 데이터 수집 완료
# 2022-06-19 데이터 수집 완료
# 2022-06-20 데이터 수집 완료
# 2022-06-21 데이터 수집 완료
# 2022-06-22 데이터 수집 완료
# 2022-06-23 데이터 수집 완료
# 2022-06-24 데이터 수집 완료
# 2022-06-25 데이터 수집 완료
# 2022-06-26 데이터 수집 완료
# 2022-06-27 데이터 수집 완료
# 2022-06-28 데이터 수집 완료
# 2022-06-29 데이터 수집 완료
# 2022-06-30 데이터 수집 완료
# 2022-07-01 데이터 수집 완료
# 2022-07-02 데이터 수집 완료
# 2022-07-03 데이터 수집 완료
# 2022-07-04 데이터 수집 완료
# 2022-07-05 데이터 수집 완료
# 2022-07-06 데이터 수집 완료
# 2022-07-07 데이터 수집 완료
# 2022-07-08 데이터 수집 완료
# 2022-07-09 데이터 수집 완료
# 2022-07-10 데이터 수집 완료
# 2022-07-11 데이터 수집 완료
# 2022-07-12 데이터 수집 완료
# 2022-07-13 데이터 수집 완료
# 2022-07-14 데이터 수집 완료
# 2022-07-15 데이터 수집 완료
# 2022-07-16 데이터 수집 완료
# 2022-07-17 데이터 수집 완료
# 2022-07-18 데이터 수집 완료
# 2022-07-19 데이터 수집 완료
# 2022-07-20 데이터 수집 완료
# 2022-07-21 데이터 수집 완료
# 2022-07-22 데이터 수집 완료
# 2022-07-23 데이터 수집 완료
# 2022-07-24 데이터 수집 완료
# 2022-07-25 데이터 수집 완료
# 2022-07-26 데이터 수집 완료
# 2022-07-27 데이터 수집 완료
# 2022-07-28 데이터 수집 완료
# 2022-07-29 데이터 수집 완료
# 2022-07-30 데이터 수집 완료
# 2022-07-31 데이터 수집 완료
# 2022-08-01 데이터 수집 완료
# 2022-08-02 데이터 수집 완료
# 2022-08-03 데이터 수집 완료
# 2022-08-04 데이터 수집 완료
# 2022-08-05 데이터 수집 완료
# 2022-08-06 데이터 수집 완료
# 2022-08-07 데이터 수집 완료
# 2022-08-08 데이터 수집 완료
# 2022-08-09 데이터 수집 완료
# 2022-08-10 데이터 수집 완료
# 2022-08-11 데이터 수집 완료
# 2022-08-12 데이터 수집 완료
# 2022-08-13 데이터 수집 완료
# 2022-08-14 데이터 수집 완료
# 2022-08-15 데이터 수집 완료
# 2022-08-16 데이터 수집 완료
# 2022-08-17 데이터 수집 완료
# 2022-08-18 데이터 수집 완료
# 2022-08-19 데이터 수집 완료
# 2022-08-20 데이터 수집 완료
# 2022-08-21 데이터 수집 완료
# 2022-08-22 데이터 수집 완료
# 2022-08-23 데이터 수집 완료
# 2022-08-24 데이터 수집 완료
# 2022-08-25 데이터 수집 완료
# 2022-08-26 데이터 수집 완료
# 2022-08-27 데이터 수집 완료
# 2022-08-28 데이터 수집 완료
# 2022-08-29 데이터 수집 완료
# 2022-08-30 데이터 수집 완료
# 2022-08-31 데이터 수집 완료
# 2022-09-01 데이터 수집 완료
# 2022-09-02 데이터 수집 완료
# 2022-09-03 데이터 수집 완료
# 2022-09-04 데이터 수집 완료
# 2022-09-05 데이터 수집 완료
# 2022-09-06 데이터 수집 완료
# 2022-09-07 데이터 수집 완료
# 2022-09-08 데이터 수집 완료
# 2022-09-09 데이터 수집 완료
# 2022-09-10 데이터 수집 완료
# 2022-09-11 데이터 수집 완료
# 2022-09-12 데이터 수집 완료
# 2022-09-13 데이터 수집 완료
# 2022-09-14 데이터 수집 완료
# 2022-09-15 데이터 수집 완료
# 2022-09-16 데이터 수집 완료
# 2022-09-17 데이터 수집 완료
# 2022-09-18 데이터 수집 완료
# 2022-09-19 데이터 수집 완료
# 2022-09-20 데이터 수집 완료
# 2022-09-21 데이터 수집 완료
# 2022-09-22 데이터 수집 완료
# 2022-09-23 데이터 수집 완료
# 2022-09-24 데이터 수집 완료
# 2022-09-25 데이터 수집 완료
# 2022-09-26 데이터 수집 완료
# 2022-09-27 데이터 수집 완료
# 2022-09-28 데이터 수집 완료
# 2022-09-29 데이터 수집 완료
# 2022-09-30 데이터 수집 완료
# 2022-10-01 데이터 수집 완료
# 2022-10-02 데이터 수집 완료
# 2022-10-03 데이터 수집 완료
# 2022-10-04 데이터 수집 완료
# 2022-10-05 데이터 수집 완료
# 2022-10-06 데이터 수집 완료
# 2022-10-07 데이터 수집 완료
# 2022-10-08 데이터 수집 완료
# 2022-10-09 데이터 수집 완료
# 2022-10-10 데이터 수집 완료
# 2022-10-11 데이터 수집 완료
# 2022-10-12 데이터 수집 완료
# 2022-10-13 데이터 수집 완료
# 2022-10-14 데이터 수집 완료
# 2022-10-15 데이터 수집 완료
# 2022-10-16 데이터 수집 완료
# 2022-10-17 데이터 수집 완료
# 2022-10-18 데이터 수집 완료
# 2022-10-19 데이터 수집 완료
# 2022-10-20 데이터 수집 완료
# 2022-10-21 데이터 수집 완료
# 2022-10-22 데이터 수집 완료
# 2022-10-23 데이터 수집 완료
# 2022-10-24 데이터 수집 완료
# 2022-10-25 데이터 수집 완료
# 2022-10-26 데이터 수집 완료
# 2022-10-27 데이터 수집 완료
# 2022-10-28 데이터 수집 완료
# 2022-10-29 데이터 수집 완료
# 2022-10-30 데이터 수집 완료
# 2022-10-31 데이터 수집 완료
# 2022-11-01 데이터 수집 완료
# 2022-11-02 데이터 수집 완료
# 2022-11-03 데이터 수집 완료
# 2022-11-04 데이터 수집 완료
# 2022-11-05 데이터 수집 완료
# 2022-11-06 데이터 수집 완료
# 2022-11-07 데이터 수집 완료
# 2022-11-08 데이터 수집 완료
# 2022-11-09 데이터 수집 완료
# 2022-11-10 데이터 수집 완료
# 2022-11-11 데이터 수집 완료
# 2022-11-12 데이터 수집 완료
# 2022-11-13 데이터 수집 완료
# 2022-11-14 데이터 수집 완료
# 2022-11-15 데이터 수집 완료
# 2022-11-16 데이터 수집 완료
# 2022-11-17 데이터 수집 완료
# 2022-11-18 데이터 수집 완료
# 2022-11-19 데이터 수집 완료
# 2022-11-20 데이터 수집 완료
# 2022-11-21 데이터 수집 완료
# 2022-11-22 데이터 수집 완료
# 2022-11-23 데이터 수집 완료
# 2022-11-24 데이터 수집 완료
# 2022-11-25 데이터 수집 완료
# 2022-11-26 데이터 수집 완료
# 2022-11-27 데이터 수집 완료
# 2022-11-28 데이터 수집 완료
# 2022-11-29 데이터 수집 완료
# 2022-11-30 데이터 수집 완료
# 2022-12-01 데이터 수집 완료
# 2022-12-02 데이터 수집 완료
# 2022-12-03 데이터 수집 완료
# 2022-12-04 데이터 수집 완료
# 2022-12-05 데이터 수집 완료
# 2022-12-06 데이터 수집 완료
# 2022-12-07 데이터 수집 완료
# 2022-12-08 데이터 수집 완료
# 2022-12-09 데이터 수집 완료
# 2022-12-10 데이터 수집 완료
# 2022-12-11 데이터 수집 완료
# 2022-12-12 데이터 수집 완료
# 2022-12-13 데이터 수집 완료
# 2022-12-14 데이터 수집 완료
# 2022-12-15 데이터 수집 완료
# 2022-12-16 데이터 수집 완료
# 2022-12-17 데이터 수집 완료
# 2022-12-18 데이터 수집 완료
# 2022-12-19 데이터 수집 완료
# 2022-12-20 데이터 수집 완료
# 2022-12-21 데이터 수집 완료
# 2022-12-22 데이터 수집 완료
# 2022-12-23 데이터 수집 완료
# 2022-12-24 데이터 수집 완료
# 2022-12-25 데이터 수집 완료
# 2022-12-26 데이터 수집 완료
# 2022-12-27 데이터 수집 완료
# 2022-12-28 데이터 수집 완료
# 2022-12-29 데이터 수집 완료
# 2022-12-30 데이터 수집 완료
# 2022-12-31 데이터 수집 완료
# 2023-01-01 데이터 수집 완료
# 2023-01-02 데이터 수집 완료
# 2023-01-03 데이터 수집 완료
# 2023-01-04 데이터 수집 완료
# 2023-01-05 데이터 수집 완료
# 2023-01-06 데이터 수집 완료
# 2023-01-07 데이터 수집 완료
# 2023-01-08 데이터 수집 완료
# 2023-01-09 데이터 수집 완료
# 2023-01-10 데이터 수집 완료
# 2023-01-11 데이터 수집 완료
# 2023-01-12 데이터 수집 완료
# 2023-01-13 데이터 수집 완료
# 2023-01-14 데이터 수집 완료
# 2023-01-15 데이터 수집 완료
# 2023-01-16 데이터 수집 완료
# 2023-01-17 데이터 수집 완료
# 2023-01-18 데이터 수집 완료
# 2023-01-19 데이터 수집 완료
# 2023-01-20 데이터 수집 완료
# 2023-01-21 데이터 수집 완료
# 2023-01-22 데이터 수집 완료
# 2023-01-23 데이터 수집 완료
# 2023-01-24 데이터 수집 완료
# 2023-01-25 데이터 수집 완료
# 2023-01-26 데이터 수집 완료
# 2023-01-27 데이터 수집 완료
# 2023-01-28 데이터 수집 완료
# 2023-01-29 데이터 수집 완료
# 2023-01-30 데이터 수집 완료
# 2023-01-31 데이터 수집 완료
# 2023-02-01 데이터 수집 완료
# 2023-02-02 데이터 수집 완료
# 2023-02-03 데이터 수집 완료
# 2023-02-04 데이터 수집 완료
# 2023-02-05 데이터 수집 완료
# 2023-02-06 데이터 수집 완료
# 2023-02-07 데이터 수집 완료
# 2023-02-08 데이터 수집 완료
# 2023-02-09 데이터 수집 완료
# 2023-02-10 데이터 수집 완료
# 2023-02-11 데이터 수집 완료
# 2023-02-12 데이터 수집 완료
# 2023-02-13 데이터 수집 완료
# 2023-02-14 데이터 수집 완료
# 2023-02-15 데이터 수집 완료
# 2023-02-16 데이터 수집 완료
# 2023-02-17 데이터 수집 완료
# 2023-02-18 데이터 수집 완료
# 2023-02-19 데이터 수집 완료
# 2023-02-20 데이터 수집 완료
# 2023-02-21 데이터 수집 완료
# 2023-02-22 데이터 수집 완료
# 2023-02-23 데이터 수집 완료
# 2023-02-24 데이터 수집 완료
# 2023-02-25 데이터 수집 완료
# 2023-02-26 데이터 수집 완료
# 2023-02-27 데이터 수집 완료
# 2023-02-28 데이터 수집 완료
# 2023-03-01 데이터 수집 완료
# 2023-03-02 데이터 수집 완료
# 2023-03-03 데이터 수집 완료
# 2023-03-04 데이터 수집 완료
# 2023-03-05 데이터 수집 완료
# 2023-03-06 데이터 수집 완료
# 2023-03-07 데이터 수집 완료
# 2023-03-08 데이터 수집 완료
# 2023-03-09 데이터 수집 완료
# 2023-03-10 데이터 수집 완료
# 2023-03-11 데이터 수집 완료
# 2023-03-12 데이터 수집 완료
# 2023-03-13 데이터 수집 완료
# 2023-03-14 데이터 수집 완료
# 2023-03-15 데이터 수집 완료
# 2023-03-16 데이터 수집 완료
# 2023-03-17 데이터 수집 완료
# 2023-03-18 데이터 수집 완료
# 2023-03-19 데이터 수집 완료
# 2023-03-20 데이터 수집 완료
# 2023-03-21 데이터 수집 완료
# 2023-03-22 데이터 수집 완료
# 2023-03-23 데이터 수집 완료
# 2023-03-24 데이터 수집 완료
# 2023-03-25 데이터 수집 완료
# 2023-03-26 데이터 수집 완료
# 2023-03-27 데이터 수집 완료
# 2023-03-28 데이터 수집 완료
# 2023-03-29 데이터 수집 완료
# 2023-03-30 데이터 수집 완료
# 2023-03-31 데이터 수집 완료
# 2023-04-01 데이터 수집 완료
# 2023-04-02 데이터 수집 완료
# 2023-04-03 데이터 수집 완료
# 2023-04-04 데이터 수집 완료
# 2023-04-05 데이터 수집 완료
# 2023-04-06 데이터 수집 완료
# 2023-04-07 데이터 수집 완료
# 2023-04-08 데이터 수집 완료
# 2023-04-09 데이터 수집 완료
# 2023-04-10 데이터 수집 완료
# 2023-04-11 데이터 수집 완료
# 2023-04-12 데이터 수집 완료
# 2023-04-13 데이터 수집 완료
# 2023-04-14 데이터 수집 완료
# 2023-04-15 데이터 수집 완료
# 2023-04-16 데이터 수집 완료
# 2023-04-17 데이터 수집 완료
# 2023-04-18 데이터 수집 완료
# 2023-04-19 데이터 수집 완료
# 2023-04-20 데이터 수집 완료
# 2023-04-21 데이터 수집 완료
# 2023-04-22 데이터 수집 완료
# 2023-04-23 데이터 수집 완료
# 2023-04-24 데이터 수집 완료
# 2023-04-25 데이터 수집 완료
# 2023-04-26 데이터 수집 완료
# 2023-04-27 데이터 수집 완료
# 2023-04-28 데이터 수집 완료
# 2023-04-29 데이터 수집 완료
# 2023-04-30 데이터 수집 완료
# 2023-05-01 데이터 수집 완료
# 2023-05-02 데이터 수집 완료
# 2023-05-03 데이터 수집 완료
# 2023-05-04 데이터 수집 완료
# 2023-05-05 데이터 수집 완료
# 2023-05-06 데이터 수집 완료
# 2023-05-07 데이터 수집 완료
# 2023-05-08 데이터 수집 완료
# 2023-05-09 데이터 수집 완료
# 2023-05-10 데이터 수집 완료
# 2023-05-11 데이터 수집 완료
# 2023-05-12 데이터 수집 완료
# 2023-05-13 데이터 수집 완료
# 2023-05-14 데이터 수집 완료
# 2023-05-15 데이터 수집 완료
# 2023-05-16 데이터 수집 완료
# 2023-05-17 데이터 수집 완료
# 2023-05-18 데이터 수집 완료
# 2023-05-19 데이터 수집 완료
# 2023-05-20 데이터 수집 완료
# 2023-05-21 데이터 수집 완료
# 2023-05-22 데이터 수집 완료
# 2023-05-23 데이터 수집 완료
# 2023-05-24 데이터 수집 완료
# 2023-05-25 데이터 수집 완료
# 2023-05-26 데이터 수집 완료
# 2023-05-27 데이터 수집 완료
# 2023-05-28 데이터 수집 완료
# 2023-05-29 데이터 수집 완료
# 2023-05-30 데이터 수집 완료
# 2023-05-31 데이터 수집 완료
# 2023-06-01 데이터 수집 완료
# 2023-06-02 데이터 수집 완료
# 2023-06-03 데이터 수집 완료
# 2023-06-04 데이터 수집 완료
# 2023-06-05 데이터 수집 완료
# 2023-06-06 데이터 수집 완료
# 2023-06-07 데이터 수집 완료
# 2023-06-08 데이터 수집 완료
# 2023-06-09 데이터 수집 완료
# 2023-06-10 데이터 수집 완료
# 2023-06-11 데이터 수집 완료
# 2023-06-12 데이터 수집 완료
# 2023-06-13 데이터 수집 완료
# 2023-06-14 데이터 수집 완료
# 2023-06-15 데이터 수집 완료
# 2023-06-16 데이터 수집 완료
# 2023-06-17 데이터 수집 완료
# 2023-06-18 데이터 수집 완료
# 2023-06-19 데이터 수집 완료
# 2023-06-20 데이터 수집 완료
# 2023-06-21 데이터 수집 완료
# 2023-06-22 데이터 수집 완료
# 2023-06-23 데이터 수집 완료
# 2023-06-24 데이터 수집 완료
# 2023-06-25 데이터 수집 완료
# 2023-06-26 데이터 수집 완료
# 2023-06-27 데이터 수집 완료
# 2023-06-28 데이터 수집 완료
# 2023-06-29 데이터 수집 완료
# 2023-06-30 데이터 수집 완료
# 2023-07-01 데이터 수집 완료
# 2023-07-02 데이터 수집 완료
# 2023-07-03 데이터 수집 완료
# 2023-07-04 데이터 수집 완료
# 2023-07-05 데이터 수집 완료
# 2023-07-06 데이터 수집 완료
# 2023-07-07 데이터 수집 완료
# 2023-07-08 데이터 수집 완료
# 2023-07-09 데이터 수집 완료
# 2023-07-10 데이터 수집 완료
# 2023-07-11 데이터 수집 완료
# 2023-07-12 데이터 수집 완료
# 2023-07-13 데이터 수집 완료
# 2023-07-14 데이터 수집 완료
# 2023-07-15 데이터 수집 완료
# 2023-07-16 데이터 수집 완료
# 2023-07-17 데이터 수집 완료
# 2023-07-18 데이터 수집 완료
# 2023-07-19 데이터 수집 완료
# 2023-07-20 데이터 수집 완료
# 2023-07-21 데이터 수집 완료
# 2023-07-22 데이터 수집 완료
# 2023-07-23 데이터 수집 완료
# 2023-07-24 데이터 수집 완료
# 2023-07-25 데이터 수집 완료
# 2023-07-26 데이터 수집 완료
# 2023-07-27 데이터 수집 완료
# 2023-07-28 데이터 수집 완료
# 2023-07-29 데이터 수집 완료
# 2023-07-30 데이터 수집 완료
# 2023-07-31 데이터 수집 완료
# 2023-08-01 데이터 수집 완료
# 2023-08-02 데이터 수집 완료
# 2023-08-03 데이터 수집 완료
# 2023-08-04 데이터 수집 완료
# 2023-08-05 데이터 수집 완료
# 2023-08-06 데이터 수집 완료
# 2023-08-07 데이터 수집 완료
# 2023-08-08 데이터 수집 완료
# 2023-08-09 데이터 수집 완료
# 2023-08-10 데이터 수집 완료
# 2023-08-11 데이터 수집 완료
# 2023-08-12 데이터 수집 완료
# 2023-08-13 데이터 수집 완료
# 2023-08-14 데이터 수집 완료
# 2023-08-15 데이터 수집 완료
# 2023-08-16 데이터 수집 완료
# 2023-08-17 데이터 수집 완료
# 2023-08-18 데이터 수집 완료
# 2023-08-19 데이터 수집 완료
# 2023-08-20 데이터 수집 완료
# 2023-08-21 데이터 수집 완료
# 2023-08-22 데이터 수집 완료
# 2023-08-23 데이터 수집 완료
# 2023-08-24 데이터 수집 완료
# 2023-08-25 데이터 수집 완료
# 2023-08-26 데이터 수집 완료
# 2023-08-27 데이터 수집 완료
# 2023-08-28 데이터 수집 완료
# 2023-08-29 데이터 수집 완료
# 2023-08-30 데이터 수집 완료
# 2023-08-31 데이터 수집 완료
# 2023-09-01 데이터 수집 완료
# 2023-09-02 데이터 수집 완료
# 2023-09-03 데이터 수집 완료
# 2023-09-04 데이터 수집 완료
# 2023-09-05 데이터 수집 완료
# 2023-09-06 데이터 수집 완료
# 2023-09-07 데이터 수집 완료
# 2023-09-08 데이터 수집 완료
# 2023-09-09 데이터 수집 완료
# 2023-09-10 데이터 수집 완료
# 2023-09-11 데이터 수집 완료
# 2023-09-12 데이터 수집 완료
# 2023-09-13 데이터 수집 완료
# 2023-09-14 데이터 수집 완료
# 2023-09-15 데이터 수집 완료
# 2023-09-16 데이터 수집 완료
# 2023-09-17 데이터 수집 완료
# 2023-09-18 데이터 수집 완료
# 2023-09-19 데이터 수집 완료
# 2023-09-20 데이터 수집 완료
# 2023-09-21 데이터 수집 완료
# 2023-09-22 데이터 수집 완료
# 2023-09-23 데이터 수집 완료
# 2023-09-24 데이터 수집 완료
# 2023-09-25 데이터 수집 완료
# 2023-09-26 데이터 수집 완료
# 2023-09-27 데이터 수집 완료
# 2023-09-28 데이터 수집 완료
# 2023-09-29 데이터 수집 완료
# 2023-09-30 데이터 수집 완료
# 2023-10-01 데이터 수집 완료
# 2023-10-02 데이터 수집 완료
# 2023-10-03 데이터 수집 완료
# 2023-10-04 데이터 수집 완료
# 2023-10-05 데이터 수집 완료
# 2023-10-06 데이터 수집 완료
# 2023-10-07 데이터 수집 완료
# 2023-10-08 데이터 수집 완료
# 2023-10-09 데이터 수집 완료
# 2023-10-10 데이터 수집 완료
# 2023-10-11 데이터 수집 완료
# 2023-10-12 데이터 수집 완료
# 2023-10-13 데이터 수집 완료
# 2023-10-14 데이터 수집 완료
# 2023-10-15 데이터 수집 완료
# 2023-10-16 데이터 수집 완료
# 2023-10-17 데이터 수집 완료
# 2023-10-18 데이터 수집 완료
# 2023-10-19 데이터 수집 완료
# 2023-10-20 데이터 수집 완료
# 2023-10-21 데이터 수집 완료
# 2023-10-22 데이터 수집 완료
# 2023-10-23 데이터 수집 완료
# 2023-10-24 데이터 수집 완료
# 2023-10-25 데이터 수집 완료
# 2023-10-26 데이터 수집 완료
# 2023-10-27 데이터 수집 완료
# 2023-10-28 데이터 수집 완료
# 2023-10-29 데이터 수집 완료
# 2023-10-30 데이터 수집 완료
# 2023-10-31 데이터 수집 완료
# 2023-11-01 데이터 수집 완료
# 2023-11-02 데이터 수집 완료
# 2023-11-03 데이터 수집 완료
# 2023-11-04 데이터 수집 완료
# 2023-11-05 데이터 수집 완료
# 2023-11-06 데이터 수집 완료
# 2023-11-07 데이터 수집 완료
# 2023-11-08 데이터 수집 완료
# 2023-11-09 데이터 수집 완료
# 2023-11-10 데이터 수집 완료
# 2023-11-11 데이터 수집 완료
# 2023-11-12 데이터 수집 완료
# 2023-11-13 데이터 수집 완료
# 2023-11-14 데이터 수집 완료
# 2023-11-15 데이터 수집 완료
# 2023-11-16 데이터 수집 완료
# 2023-11-17 데이터 수집 완료
# 2023-11-18 데이터 수집 완료
# 2023-11-19 데이터 수집 완료
# 2023-11-20 데이터 수집 완료
# 2023-11-21 데이터 수집 완료
# 2023-11-22 데이터 수집 완료
# 2023-11-23 데이터 수집 완료
# 2023-11-24 데이터 수집 완료
# 2023-11-25 데이터 수집 완료
# 2023-11-26 데이터 수집 완료
# 2023-11-27 데이터 수집 완료
# 2023-11-28 데이터 수집 완료
# 2023-11-29 데이터 수집 완료
# 2023-11-30 데이터 수집 완료
# 2023-12-01 데이터 수집 완료
# 2023-12-02 데이터 수집 완료
# 2023-12-03 데이터 수집 완료
# 2023-12-04 데이터 수집 완료
# 2023-12-05 데이터 수집 완료
# 2023-12-06 데이터 수집 완료
# 2023-12-07 데이터 수집 완료
# 2023-12-08 데이터 수집 완료
# 2023-12-09 데이터 수집 완료
# 2023-12-10 데이터 수집 완료
# 2023-12-11 데이터 수집 완료
# 2023-12-12 데이터 수집 완료
# 2023-12-13 데이터 수집 완료
# 2023-12-14 데이터 수집 완료
# 2023-12-15 데이터 수집 완료
# 2023-12-16 데이터 수집 완료
# 2023-12-17 데이터 수집 완료
# 2023-12-18 데이터 수집 완료
# 2023-12-19 데이터 수집 완료
# 2023-12-20 데이터 수집 완료
# 2023-12-21 데이터 수집 완료
# 2023-12-22 데이터 수집 완료
# 2023-12-23 데이터 수집 완료
# 2023-12-24 데이터 수집 완료
# 2023-12-25 데이터 수집 완료
# 2023-12-26 데이터 수집 완료
# 2023-12-27 데이터 수집 완료
# 2023-12-28 데이터 수집 완료
# 2023-12-29 데이터 수집 완료
# 2023-12-30 데이터 수집 완료
# 2023-12-31 데이터 수집 완료
# 2024-01-01 데이터 수집 완료
# 2024-01-02 데이터 수집 완료
# 2024-01-03 데이터 수집 완료
# 2024-01-04 데이터 수집 완료
# 2024-01-05 데이터 수집 완료
# 2024-01-06 데이터 수집 완료
# 2024-01-07 데이터 수집 완료
# 2024-01-08 데이터 수집 완료
# 2024-01-09 데이터 수집 완료
# 2024-01-10 데이터 수집 완료
# 2024-01-11 데이터 수집 완료
# 2024-01-12 데이터 수집 완료
# 2024-01-13 데이터 수집 완료
# 2024-01-14 데이터 수집 완료
# 2024-01-15 데이터 수집 완료
# 2024-01-16 데이터 수집 완료
# 2024-01-17 데이터 수집 완료
# 2024-01-18 데이터 수집 완료
# 2024-01-19 데이터 수집 완료
# 2024-01-20 데이터 수집 완료
# 2024-01-21 데이터 수집 완료
# 2024-01-22 데이터 수집 완료
# 2024-01-23 데이터 수집 완료
# 2024-01-24 데이터 수집 완료
# 2024-01-25 데이터 수집 완료
# 2024-01-26 데이터 수집 완료
# 2024-01-27 데이터 수집 완료
# 2024-01-28 데이터 수집 완료
# 2024-01-29 데이터 수집 완료
# 2024-01-30 데이터 수집 완료
# 2024-01-31 데이터 수집 완료
# 2024-02-01 데이터 수집 완료
# 2024-02-02 데이터 수집 완료
# 2024-02-03 데이터 수집 완료
# 2024-02-04 데이터 수집 완료
# 2024-02-05 데이터 수집 완료
# 2024-02-06 데이터 수집 완료
# 2024-02-07 데이터 수집 완료
# 2024-02-08 데이터 수집 완료
# 2024-02-09 데이터 수집 완료
# 2024-02-10 데이터 수집 완료
# 2024-02-11 데이터 수집 완료
# 2024-02-12 데이터 수집 완료
# 2024-02-13 데이터 수집 완료
# 2024-02-14 데이터 수집 완료
# 2024-02-15 데이터 수집 완료
# 2024-02-16 데이터 수집 완료
# 2024-02-17 데이터 수집 완료
# 2024-02-18 데이터 수집 완료
# 2024-02-19 데이터 수집 완료
# 2024-02-20 데이터 수집 완료
# 2024-02-21 데이터 수집 완료
# 2024-02-22 데이터 수집 완료
# 2024-02-23 데이터 수집 완료
# 2024-02-24 데이터 수집 완료
# 2024-02-25 데이터 수집 완료
# 2024-02-26 데이터 수집 완료
# 2024-02-27 데이터 수집 완료
# 2024-02-28 데이터 수집 완료
# 2024-02-29 데이터 수집 완료
# 2024-03-01 데이터 수집 완료
# 2024-03-02 데이터 수집 완료
# 2024-03-03 데이터 수집 완료
# 2024-03-04 데이터 수집 완료
# 2024-03-05 데이터 수집 완료
# 2024-03-06 데이터 수집 완료
# 2024-03-07 데이터 수집 완료
# 2024-03-08 데이터 수집 완료
# 2024-03-09 데이터 수집 완료
# 2024-03-10 데이터 수집 완료
# 2024-03-11 데이터 수집 완료
# 2024-03-12 데이터 수집 완료
# 2024-03-13 데이터 수집 완료
# 2024-03-14 데이터 수집 완료
# 2024-03-15 데이터 수집 완료
# 2024-03-16 데이터 수집 완료
# 2024-03-17 데이터 수집 완료
# 2024-03-18 데이터 수집 완료
# 2024-03-19 데이터 수집 완료
# 2024-03-20 데이터 수집 완료
# 2024-03-21 데이터 수집 완료
# 2024-03-22 데이터 수집 완료
# 2024-03-23 데이터 수집 완료
# 2024-03-24 데이터 수집 완료
# 2024-03-25 데이터 수집 완료
# 2024-03-26 데이터 수집 완료
# 2024-03-27 데이터 수집 완료
# 2024-03-28 데이터 수집 완료
# 2024-03-29 데이터 수집 완료
# 2024-03-30 데이터 수집 완료
# 2024-03-31 데이터 수집 완료
# 2024-04-01 데이터 수집 완료
# 2024-04-02 데이터 수집 완료
# 2024-04-03 데이터 수집 완료
# 2024-04-04 데이터 수집 완료
# 2024-04-05 데이터 수집 완료
# 2024-04-06 데이터 수집 완료
# 2024-04-07 데이터 수집 완료
# 2024-04-08 데이터 수집 완료
# 2024-04-09 데이터 수집 완료
# 2024-04-10 데이터 수집 완료
# 2024-04-11 데이터 수집 완료
# 2024-04-12 데이터 수집 완료
# 2024-04-13 데이터 수집 완료
# 2024-04-14 데이터 수집 완료
# 2024-04-15 데이터 수집 완료
# 2024-04-16 데이터 수집 완료
# 2024-04-17 데이터 수집 완료
# 2024-04-18 데이터 수집 완료
# 2024-04-19 데이터 수집 완료
# 2024-04-20 데이터 수집 완료
# 2024-04-21 데이터 수집 완료
# 2024-04-22 데이터 수집 완료
# 2024-04-23 데이터 수집 완료
# 2024-04-24 데이터 수집 완료
# 2024-04-25 데이터 수집 완료
# 2024-04-26 데이터 수집 완료
# 2024-04-27 데이터 수집 완료
# 2024-04-28 데이터 수집 완료
# 2024-04-29 데이터 수집 완료
# 2024-04-30 데이터 수집 완료
# 2024-05-01 데이터 수집 완료
# 2024-05-02 데이터 수집 완료
# 2024-05-03 데이터 수집 완료
# 2024-05-04 데이터 수집 완료
# 2024-05-05 데이터 수집 완료
# 2024-05-06 데이터 수집 완료
# 2024-05-07 데이터 수집 완료
# 2024-05-08 데이터 수집 완료
# 2024-05-09 데이터 수집 완료
# 2024-05-10 데이터 수집 완료
# 2024-05-11 데이터 수집 완료
# 2024-05-12 데이터 수집 완료
# 2024-05-13 데이터 수집 완료
# 2024-05-14 데이터 수집 완료
# 2024-05-15 데이터 수집 완료
# 2024-05-16 데이터 수집 완료
# 2024-05-17 데이터 수집 완료
# 2024-05-18 데이터 수집 완료
# 2024-05-19 데이터 수집 완료
# 2024-05-20 데이터 수집 완료
# 2024-05-21 데이터 수집 완료
# 2024-05-22 데이터 수집 완료
# 2024-05-23 데이터 수집 완료
# 2024-05-24 데이터 수집 완료
# 2024-05-25 데이터 수집 완료
# 2024-05-26 데이터 수집 완료
# 2024-05-27 데이터 수집 완료
# 2024-05-28 데이터 수집 완료
# 2024-05-29 데이터 수집 완료
# 2024-05-30 데이터 수집 완료
# 2024-05-31 데이터 수집 완료
# 2024-06-01 데이터 수집 완료
# 2024-06-02 데이터 수집 완료
# 2024-06-03 데이터 수집 완료
# 2024-06-04 데이터 수집 완료
# 2024-06-05 데이터 수집 완료
# 2024-06-06 데이터 수집 완료
# 2024-06-07 데이터 수집 완료
# 2024-06-08 데이터 수집 완료
# 2024-06-09 데이터 수집 완료
# 2024-06-10 데이터 수집 완료
# 2024-06-11 데이터 수집 완료
# 2024-06-12 데이터 수집 완료
# 2024-06-13 데이터 수집 완료
# 2024-06-14 데이터 수집 완료
# 2024-06-15 데이터 수집 완료
# 2024-06-16 데이터 수집 완료
# 2024-06-17 데이터 수집 완료
# 2024-06-18 데이터 수집 완료
# 2024-06-19 데이터 수집 완료
# 2024-06-20 데이터 수집 완료
# 2024-06-21 데이터 수집 완료
# 2024-06-22 데이터 수집 완료
# 2024-06-23 데이터 수집 완료
# 2024-06-24 데이터 수집 완료
# 2024-06-25 데이터 수집 완료
# 2024-06-26 데이터 수집 완료
# 2024-06-27 데이터 수집 완료
# 2024-06-28 데이터 수집 완료
# 2024-06-29 데이터 수집 완료
# 2024-06-30 데이터 수집 완료
# 2024-07-01 데이터 수집 완료
# 2024-07-02 데이터 수집 완료
# 2024-07-03 데이터 수집 완료
# 2024-07-04 데이터 수집 완료
# 2024-07-05 데이터 수집 완료
# 모든 데이터 수집 완료
#             Date Rank Team Year    AVG   G  PA  AB  R   H  ... HP IB  SO GDP  \
# 0     2021-04-03    1   키움   21  0.250  13  36  32  6   8  ...  0  1   8   0
# 1     2021-04-03    2   삼성   21  0.194   9  32  31  1   6  ...  0  0   3   1
# 2     2021-04-04    1   키움   21  0.344  13  40  32  7  11  ...  2  0   6   1
# 3     2021-04-04    2   롯데   21  0.324  13  38  37  3  12  ...  0  0   5   1
# 4     2021-04-04    3  SSG   21  0.290  10  34  31  5   9  ...  0  0   8   2
# ...          ...  ...  ...  ...    ...  ..  ..  .. ..  ..  ... .. ..  ..  ..
# 5043  2024-07-04    6  SSG   24  0.175  15  44  40  0   7  ...  0  0  11   0
# 5044  2024-07-04    7   삼성   24  0.161  13  33  31  3   5  ...  0  0   8   0
# 5045  2024-07-04    8   키움   24  0.129  12  36  31  2   4  ...  1  0   7   0
# 5046  2024-07-04    9   롯데   24  0.121  14  42  33  3   4  ...  2  0  13   0
# 5047  2024-07-04   10   NC   24  0.081  12  40  37  2   3  ...  1  0  12   0
#
#      SH SF    AVG    OBP    SLG    OPS
# 0     0  0  0.250  0.333  0.375  0.708
# 1     0  0  0.194  0.219  0.194  0.413
# 2     0  0  0.344  0.475  0.563  1.038
# 3     0  0  0.324  0.342  0.514  0.856
# 4     0  0  0.290  0.353  0.710  1.063
# ...  .. ..    ...    ...    ...    ...
# 5043  2  0  0.175  0.214  0.225  0.439
# 5044  0  0  0.161  0.212  0.355  0.567
# 5045  0  0  0.129  0.250  0.161  0.411
# 5046  0  0  0.121  0.310  0.182  0.492
# 5047  0  0  0.081  0.150  0.162  0.312
#
# [5048 rows x 30 columns]

# %%
team_batting_data
# Out:
#             Date Rank Team Year    AVG   G  PA  AB  R   H  ... HP IB  SO GDP  \
# 0     2021-04-03    1   키움   21  0.250  13  36  32  6   8  ...  0  1   8   0
# 1     2021-04-03    2   삼성   21  0.194   9  32  31  1   6  ...  0  0   3   1
# 2     2021-04-04    1   키움   21  0.344  13  40  32  7  11  ...  2  0   6   1
# 3     2021-04-04    2   롯데   21  0.324  13  38  37  3  12  ...  0  0   5   1
# 4     2021-04-04    3  SSG   21  0.290  10  34  31  5   9  ...  0  0   8   2
# ...          ...  ...  ...  ...    ...  ..  ..  .. ..  ..  ... .. ..  ..  ..
# 5043  2024-07-04    6  SSG   24  0.175  15  44  40  0   7  ...  0  0  11   0
# 5044  2024-07-04    7   삼성   24  0.161  13  33  31  3   5  ...  0  0   8   0
# 5045  2024-07-04    8   키움   24  0.129  12  36  31  2   4  ...  1  0   7   0
# 5046  2024-07-04    9   롯데   24  0.121  14  42  33  3   4  ...  2  0  13   0
# 5047  2024-07-04   10   NC   24  0.081  12  40  37  2   3  ...  1  0  12   0
#
#      SH SF    AVG    OBP    SLG    OPS
# 0     0  0  0.250  0.333  0.375  0.708
# 1     0  0  0.194  0.219  0.194  0.413
# 2     0  0  0.344  0.475  0.563  1.038
# 3     0  0  0.324  0.342  0.514  0.856
# 4     0  0  0.290  0.353  0.710  1.063
# ...  .. ..    ...    ...    ...    ...
# 5043  2  0  0.175  0.214  0.225  0.439
# 5044  0  0  0.161  0.212  0.355  0.567
# 5045  0  0  0.129  0.250  0.161  0.411
# 5046  0  0  0.121  0.310  0.182  0.492
# 5047  0  0  0.081  0.150  0.162  0.312
#
# [5048 rows x 30 columns]

# %%
team_batting_data = team_batting_data.drop(columns=["Rank", "Year"])
team_batting_data
# Out:
#             Date Team    AVG   G  PA  AB  R   H 2B 3B  ... HP IB  SO GDP SH  \
# 0     2021-04-03   키움  0.250  13  36  32  6   8  4  0  ...  0  1   8   0  0
# 1     2021-04-03   삼성  0.194   9  32  31  1   6  0  0  ...  0  0   3   1  0
# 2     2021-04-04   키움  0.344  13  40  32  7  11  1  0  ...  2  0   6   1  0
# 3     2021-04-04   롯데  0.324  13  38  37  3  12  1  0  ...  0  0   5   1  0
# 4     2021-04-04  SSG  0.290  10  34  31  5   9  1  0  ...  0  0   8   2  0
# ...          ...  ...    ...  ..  ..  .. ..  .. .. ..  ... .. ..  ..  .. ..
# 5043  2024-07-04  SSG  0.175  15  44  40  0   7  2  0  ...  0  0  11   0  2
# 5044  2024-07-04   삼성  0.161  13  33  31  3   5  0  0  ...  0  0   8   0  0
# 5045  2024-07-04   키움  0.129  12  36  31  2   4  1  0  ...  1  0   7   0  0
# 5046  2024-07-04   롯데  0.121  14  42  33  3   4  2  0  ...  2  0  13   0  0
# 5047  2024-07-04   NC  0.081  12  40  37  2   3  0  0  ...  1  0  12   0  0
#
#      SF    AVG    OBP    SLG    OPS
# 0     0  0.250  0.333  0.375  0.708
# 1     0  0.194  0.219  0.194  0.413
# 2     0  0.344  0.475  0.563  1.038
# 3     0  0.324  0.342  0.514  0.856
# 4     0  0.290  0.353  0.710  1.063
# ...  ..    ...    ...    ...    ...
# 5043  0  0.175  0.214  0.225  0.439
# 5044  0  0.161  0.212  0.355  0.567
# 5045  0  0.129  0.250  0.161  0.411
# 5046  0  0.121  0.310  0.182  0.492
# 5047  0  0.081  0.150  0.162  0.312
#
# [5048 rows x 28 columns]

# %%
team_batting_data.to_csv('team_batting_final.csv', index=False, encoding='utf-8-sig')

# %%
# 21시즌 완성본
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# 시즌 시작일과 종료일 설정
start_date = datetime(2021, 4, 3)  # 시즌 시작일
end_date = datetime(2021, 10, 31)  # 시즌 종료일

# 데이터를 저장할 빈 DataFrame 생성
columns = ["Date", "Rank", "Team", "Year", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SB", "CS", "GO", "FO", "BB", "HP", "IB", "SO", "GDP", "SH", "SF", "AVG", "OBP", "SLG", "OPS"]
all_data = pd.DataFrame(columns=columns)

# 날짜별로 데이터를 가져오기
current_date = start_date
while current_date <= end_date:
    # 날짜를 URL에 맞는 형식으로 변환
    date_str = current_date.strftime("%m-%d")  # 'MM-DD' 형식
    url = f"https://statiz.sporki.com/stats/?m=team&m2=batting&m3=situation1&so=&ob=&year=2021&sy=2021&ey=2021&te=&po=&lt=10100&reg=&pe=I&ds={date_str}&de={date_str}&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2="

    # 페이지 가져오기
    response = requests.get(url)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')

    # 테이블 추출
    tables = soup.find_all('table')
    if len(tables) < 2:  # 테이블이 없으면 다음 날짜로 넘어감
        print(f"{current_date.strftime('%Y-%m-%d')} 데이터 없음")
        current_date += timedelta(days=1)
        continue

    table = tables[1]
    rows = table.find('tbody').find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols]
        data.append(cols)

    # DataFrame 변환
    df = pd.DataFrame(data, columns=columns[1:])  # "Date" 제외한 열
    df.insert(0, "Date", current_date.strftime('%Y-%m-%d'))  # Date 열 추가

    # 전체 데이터에 합치기
    all_data = pd.concat([all_data, df], ignore_index=True)

    #print(f"{current_date.strftime('%Y-%m-%d')} 데이터 수집 완료")

    # 다음 날짜로 이동
    current_date += timedelta(days=1)

print("모든 데이터 수집 완료")
# 최종 데이터프레임 출력
all_data
all_data.to_csv('statiz_team_batting_records.csv', index=False)
# Out:
# 모든 데이터 수집 완료
#             Date Rank Team Year    AVG   G  PA  AB  R   H  ... HP IB SO GDP  \
# 0     2021-04-03    1   키움   21  0.250  13  36  32  6   8  ...  0  1  8   0
# 1     2021-04-03    2   삼성   21  0.194   9  32  31  1   6  ...  0  0  3   1
# 2     2021-04-04    1   키움   21  0.344  13  40  32  7  11  ...  2  0  6   1
# 3     2021-04-04    2   롯데   21  0.324  13  38  37  3  12  ...  0  0  5   1
# 4     2021-04-04    3  SSG   21  0.290  10  34  31  5   9  ...  0  0  8   2
# ...          ...  ...  ...  ...    ...  ..  ..  .. ..  ..  ... .. .. ..  ..
# 1371  2021-10-30    6   NC   21  0.278  12  40  36  5  10  ...  0  0  7   2
# 1372  2021-10-30    7   두산   21  0.242  15  39  33  5   8  ...  0  1  5   0
# 1373  2021-10-30    8   한화   21  0.206  13  35  34  3   7  ...  0  0  8   0
# 1374  2021-10-30    9  KIA   21  0.161  10  31  31  1   5  ...  0  0  7   1
# 1375  2021-10-30   10   LG   21  0.103  13  37  29  2   3  ...  1  0  7   0
#
#      SH SF    AVG    OBP    SLG    OPS
# 0     0  0  0.250  0.333  0.375  0.708
# 1     0  0  0.194  0.219  0.194  0.413
# 2     0  0  0.344  0.475  0.563  1.038
# 3     0  0  0.324  0.342  0.514  0.856
# 4     0  0  0.290  0.353  0.710  1.063
# ...  .. ..    ...    ...    ...    ...
# 1371  0  0  0.278  0.350  0.472  0.822
# 1372  1  1  0.242  0.316  0.364  0.680
# 1373  0  0  0.206  0.229  0.265  0.494
# 1374  0  0  0.161  0.161  0.258  0.419
# 1375  1  0  0.103  0.278  0.276  0.554
#
# [1376 rows x 30 columns]

# %%
all_data
# Out:
#             Date Rank Team Year    AVG   G  PA  AB  R   H  ... HP IB SO GDP  \
# 0     2021-04-03    1   키움   21  0.250  13  36  32  6   8  ...  0  1  8   0
# 1     2021-04-03    2   삼성   21  0.194   9  32  31  1   6  ...  0  0  3   1
# 2     2021-04-04    1   키움   21  0.344  13  40  32  7  11  ...  2  0  6   1
# 3     2021-04-04    2   롯데   21  0.324  13  38  37  3  12  ...  0  0  5   1
# 4     2021-04-04    3  SSG   21  0.290  10  34  31  5   9  ...  0  0  8   2
# ...          ...  ...  ...  ...    ...  ..  ..  .. ..  ..  ... .. .. ..  ..
# 1371  2021-10-30    6   NC   21  0.278  12  40  36  5  10  ...  0  0  7   2
# 1372  2021-10-30    7   두산   21  0.242  15  39  33  5   8  ...  0  1  5   0
# 1373  2021-10-30    8   한화   21  0.206  13  35  34  3   7  ...  0  0  8   0
# 1374  2021-10-30    9  KIA   21  0.161  10  31  31  1   5  ...  0  0  7   1
# 1375  2021-10-30   10   LG   21  0.103  13  37  29  2   3  ...  1  0  7   0
#
#      SH SF    AVG    OBP    SLG    OPS
# 0     0  0  0.250  0.333  0.375  0.708
# 1     0  0  0.194  0.219  0.194  0.413
# 2     0  0  0.344  0.475  0.563  1.038
# 3     0  0  0.324  0.342  0.514  0.856
# 4     0  0  0.290  0.353  0.710  1.063
# ...  .. ..    ...    ...    ...    ...
# 1371  0  0  0.278  0.350  0.472  0.822
# 1372  1  1  0.242  0.316  0.364  0.680
# 1373  0  0  0.206  0.229  0.265  0.494
# 1374  0  0  0.161  0.161  0.258  0.419
# 1375  1  0  0.103  0.278  0.276  0.554
#
# [1376 rows x 30 columns]

# %%
#이게 진짜임
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# URL 가져오기
url = "https://statiz.sporki.com/stats/?m=team&m2=batting&m3=situation1&so=&ob=&year=2021&sy=2021&ey=2021&te=&po=&lt=10100&reg=&pe=I&ds=04-03&de=04-03&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2="
response = requests.get(url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'html.parser')

# URL에서 날짜 추출
date_match = re.search(r'ds=(\d{2}-\d{2})&de=', url)
if date_match:
    date = f"2021-{date_match.group(1)}"  # 2021년을 추가 (URL에서 명시되어 있음)
else:
    date = "Unknown"  # 날짜를 추출하지 못한 경우

# 테이블 찾기
tables = soup.find_all('table')  # 페이지에 있는 모든 테이블 가져오기
print(f"총 {len(tables)}개의 테이블이 발견되었습니다.")

# 첫 번째 테이블 가져오기
table = tables[1]  # 필요한 경우 인덱스를 조정

# 테이블 데이터 추출
rows = table.find('tbody').find_all('tr')
data = []
for row in rows:
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)

# pandas DataFrame으로 변환
columns = ["Rank", "Team", "Year", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SB", "CS", "GO", "FO", "BB", "HP", "IB", "SO", "GDP", "SH", "SF", "AVG", "OBP", "SLG", "OPS"]
df = pd.DataFrame(data, columns=columns)

# 날짜(Date) 열 추가
df.insert(0, "Date", date)  # 데이터프레임의 첫 번째 열에 추가

df
# Out:
# 총 2개의 테이블이 발견되었습니다.
#          Date Rank Team Year    AVG   G  PA  AB  R  H  ... HP IB SO GDP SH SF  \
# 0  2021-04-03    1   키움   21  0.250  13  36  32  6  8  ...  0  1  8   0  0  0
# 1  2021-04-03    2   삼성   21  0.194   9  32  31  1  6  ...  0  0  3   1  0  0
#
#      AVG    OBP    SLG    OPS
# 0  0.250  0.333  0.375  0.708
# 1  0.194  0.219  0.194  0.413
#
# [2 rows x 30 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL 가져오기
url = "https://statiz.sporki.com/stats/?m=team&m2=batting&m3=situation1&so=&ob=&year=2021&sy=2021&ey=2021&te=&po=&lt=10100&reg=&pe=I&ds=04-03&de=04-03&we=&hr=&ha=&ct=&st=&vp=&bo=&pt=&pp=&ii=&vc=&um=&oo=&rr=&sc=&bc=&ba=&li=&as=&ae=&pl=&gc=&lr=&pr=50&ph=&hs=&us=&na=&ls=&sf1=&sk1=&sv1=&sf2=&sk2=&sv2="
response = requests.get(url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, 'html.parser')

# 테이블 찾기
tables = soup.find_all('table')  # 페이지에 있는 모든 테이블 가져오기
print(f"총 {len(tables)}개의 테이블이 발견되었습니다.")

# 첫 번째 테이블 가져오기
table = tables[1]  # 필요한 경우 인덱스를 조정

# 테이블 데이터 추출
rows = table.find('tbody').find_all('tr')
data = []
for row in rows:
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)

# pandas DataFrame으로 변환
columns = ["Rank", "Team", "Year", "AVG", "G", "PA", "AB", "R", "H", "2B", "3B", "HR", "TB", "RBI", "SB", "CS", "GO", "FO", "BB", "HP", "IB", "SO", "GDP", "SH", "SF", "AVG", "OBP", "SLG", "OPS"]
df = pd.DataFrame(data, columns=columns)

# 결과 출력
df
# Out:
# 총 2개의 테이블이 발견되었습니다.
#   Rank Team Year    AVG   G  PA  AB  R  H 2B  ... HP IB SO GDP SH SF    AVG  \
# 0    1   키움   21  0.250  13  36  32  6  8  4  ...  0  1  8   0  0  0  0.250
# 1    2   삼성   21  0.194   9  32  31  1  6  0  ...  0  0  3   1  0  0  0.194
#
#      OBP    SLG    OPS
# 0  0.333  0.375  0.708
# 1  0.219  0.194  0.413
#
# [2 rows x 29 columns]
# Warning: Total number of columns (29) exceeds max_columns (20) limiting to first (20) columns.

# %%
df = pd.read_csv('statiz_team_batting_records.csv')

# %%
df
# Out:
#     2B  3B   AB  BB  CS        Date   FO    G  GDP   GO  ...  SB  SF  SH  SO  \
# 0    4   0   63   5   0  2021-04-03   10   22    1   27  ...   0   0   0  11
# 1    9   1  326  37   3  2021-04-04   81  119   10   86  ...  11   2   3  72
# 2   11   1  336  25   4  2021-04-06   76  121    5   95  ...   7   4   2  88
# 3   20   0  365  60   2  2021-04-07   84  138    7  111  ...   7   1   4  65
# 4    9   2  323  54   3  2021-04-08   89  126   10   95  ...   7   3   4  65
# 5   21   2  352  39   1  2021-04-09   75  128    8   98  ...   5   5   2  76
# 6   26   0  352  42   4  2021-04-10   74  125    5   92  ...   8   2   1  77
# 7   14   2  334  42   4  2021-04-11   88  118    4   85  ...   6   2   6  83
# 8    8   1  335  46   1  2021-04-13   85  117    9   91  ...   6   4   2  73
# 9   15   0  333  34   3  2021-04-14   87  123    9  101  ...  10   3   4  73
# 10  20   1  337  40   2  2021-04-15   81  122    7   93  ...   9   2   3  72
# 11  19   0  339  50   2  2021-04-16   86  128    7   87  ...   4   3   4  67
# 12  17   5  348  52   2  2021-04-17   94  122    8   73  ...  10   3   2  84
# 13  16   0  339  47   3  2021-04-18  105  130    5   79  ...   2   4   1  72
#
#     Season   TB     Team  Year     비율    정렬▼
# 0       리그   18  Unknown    21  0.222  0.222
# 1       리그  127  Unknown    21  0.255  0.255
# 2       리그  113  Unknown    21  0.217  0.217
# 3       리그  127  Unknown    21  0.268  0.268
# 4       리그  111  Unknown    21  0.229  0.229
# 5       리그  140  Unknown    21  0.293  0.293
# 6       리그  163  Unknown    21  0.287  0.287
# 7       리그  110  Unknown    21  0.231  0.231
# 8       리그  108  Unknown    21  0.248  0.248
# 9       리그   94  Unknown    21  0.201  0.201
# 10      리그  127  Unknown    21  0.258  0.258
# 11      리그  131  Unknown    21  0.286  0.286
# 12      리그  147  Unknown    21  0.267  0.267
# 13      리그  135  Unknown    21  0.245  0.245
#
# [14 rows x 28 columns]
